# %%
# !pip install Beautifulsoup4
# Out:
# Requirement already satisfied: Beautifulsoup4 in c:\users\pooja sinalkar\anaconda3\lib\site-packages (4.9.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\pooja sinalkar\anaconda3\lib\site-packages (from Beautifulsoup4) (2.2.1)

# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in c:\users\pooja sinalkar\anaconda3\lib\site-packages (2.25.1)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\pooja sinalkar\anaconda3\lib\site-packages (from requests) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\pooja sinalkar\anaconda3\lib\site-packages (from requests) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\pooja sinalkar\anaconda3\lib\site-packages (from requests) (1.26.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pooja sinalkar\anaconda3\lib\site-packages (from requests) (2020.12.5)

# %%
import requests
from bs4 import BeautifulSoup as bts
import pandas as pd

# %%
URL="https://www.bgr.in/gadgets/mobile-phones/search/"
res=[]  # to save the final result
no_of_pages=15

# %%
for _ in range(no_of_pages):
    r = requests.get(URL)   # request is used to call URL and get the content of html page
                           # use the beautiful soup to parse the html page
    soup = bts(r.content,'html5lib') #if this line causes an error run 'pip install html5lib' or install html5lib   
    a=soup.findAll("li",class_='mobile-listing') # get all the link of mobile specs : in fig 1
                                                 # travers over the mobile spec links to scrap the specs
    for k in a:
        data={} #save the spec of mobile in it
                # open the mobile spec link
        url_temp=k.find('a')['href']
        mob=requests.get(url_temp)
        mob=bts(mob.content,'html5lib') #parse the html page of mobile spec : fig 2
         
        #print(mob)
        info=mob.find_all('span',class_='col-xs-12 col-sm-5 spec-lbl')
        #get the col 1 from spec table
        desc=mob.find_all('span',class_='col-xs-12 col-sm-7 spec-val')
        #get the col 2 from spec table
        name=mob.find('h1',{'itemprop':'name'})
        data['name']=name.get_text()
        #get the name of mobile phone
        price=mob.find("span",class_='rsm').get_text()
        #get the price of that mobile
        
        
        for k,v in zip(info,desc):
            data[k.get_text()]=v.get_text()
        data['price']=price
        res.append(data)              # store the result into list
        
        URL=soup.find('a',class_='next pagination')['href']
        #get the URL for moving to page 2

# %%
# pd.DataFrame(res).to_csv("Mobilr_data.csv") #to dataframe into csv file

# %%
df=pd.DataFrame(res)
df
# Out:
#                        name Device Type Sim Capability Input Mechanism  \
# 0                 Realme 8i  Smartphone       Dual-SIM     Touchscreen
# 1              Realme 8s 5G  Smartphone       Dual-SIM     Touchscreen
# 2     Xiaomi Redmi 10 Prime  Smartphone       Dual-SIM     Touchscreen
# 3    Samsung Galaxy A52s 5G  Smartphone       Dual-SIM     Touchscreen
# 4     Samsung Galaxy M32 5G  Smartphone       Dual-SIM     Touchscreen
# ..                      ...         ...            ...             ...
# 145                Vivo Y11  Smartphone       Dual-SIM     Touchscreen
# 146              Realme C11  Smartphone       Dual-SIM     Touchscreen
# 147             Poco M2 Pro  Smartphone       Dual-SIM     Touchscreen
# 148            OnePlus Nord  Smartphone       Dual-SIM     Touchscreen
# 149               Realme X3  Smartphone            NaN          QWERTY
#
#             Availability                            Software  \
# 0     Available In India  realme UI 2.0  Based on Android 11
# 1     Available In India  realme UI 2.0  Based on Android 11
# 2     Available In India       MIUI 12.5 based on Android 11
# 3     Available In India                          Android 11
# 4     Available In India                          Android 11
# ..                   ...                                 ...
# 145   Available In India    Funtouch OS 9 Based on Android 9
# 146   Available In India       Realme UI Based on Android 10
# 147   Available In India         MIUI 11 based on Android 10
# 148   Available In India        OxygenOS based on Android 10
# 149   Available in India                          Android 10
#
#                          Processor Internal Memory Internal Storage  \
# 0               MediaTek Helio G96             4GB             64GB
# 1        MediaTek Dimensity 810 5G             6GB            128GB
# 2               MediaTek Helio G88             4GB             64GB
# 3         Qualcomm Snapdragon 778G             6GB            128GB
# 4           MediaTek Dimensity 720             6GB            128GB
# ..                             ...             ...              ...
# 145        Qualcomm Snapdragon 439           3GB               32GB
# 146             MediaTek Helio G35            2GB              32GB
# 147       Qualcomm Snapdragon 720G             4GB             64GB
# 148      Qualcomm Snapdragon 765G              6GB             64GB
# 149  Snapdragon 855 Plus processor       6GB+128GB              NaN
#
#     Dedicated Micro SD Card  ... Fast Charging Wireless Charging Network Type  \
# 0                       Yes  ...           Yes                No          GSM
# 1                       Yes  ...           Yes                No          GSM
# 2                       Yes  ...           Yes                No          GSM
# 3                       Yes  ...           Yes                No          GSM
# 4                       Yes  ...           Yes                No          GSM
# ..                      ...  ...           ...               ...          ...
# 145                     Yes  ...            No                No          GSM
# 146                     Yes  ...            No                No          GSM
# 147                     Yes  ...           Yes                No          GSM
# 148                     Yes  ...           Yes            Select          GSM
# 149                     NaN  ...           NaN               NaN   2G, 3G, 4G
#
#     Network Capability     Fingerprint Sensor Face Unlock    price IP Rating  \
# 0           2G, 3G, 4G           Side-Mounted         Yes   13,999       NaN
# 1       2G, 3G, 4G, 5G           Side-Mounted         Yes   17,999       NaN
# 2           2G, 3G, 4G           Side-Mounted         Yes   12,499       NaN
# 3           2G, 3G, 4G          Under-Display         Yes   35,999       NaN
# 4       2G, 3G, 4G, 5G           Side-Mounted         Yes   20,999       NaN
# ..                 ...                    ...         ...      ...       ...
# 145         2G, 3G, 4G           Rear-Mounted          No    9,990       NaN
# 146         2G, 3G, 4G  No Fingerprint Sensor          No    7,499       NaN
# 147         2G, 3G, 4G           Side-Mounted         Yes   13,999       NaN
# 148     2G, 3G, 4G, 5G          Under-Display         Yes   24,999       NaN
# 149           2G,3G,4G                    NaN         NaN   24,999       NaN
#
#     SD Card Capacity Dual Sim Capability
# 0                NaN                 NaN
# 1                NaN                 NaN
# 2                NaN                 NaN
# 3                NaN                 NaN
# 4                NaN                 NaN
# ..               ...                 ...
# 145           256GB                  NaN
# 146           256 GB                 NaN
# 147            512GB                 NaN
# 148              NaN                 NaN
# 149              NaN            Dual Sim
#
# [150 rows x 30 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 30 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   name                     150 non-null    object
#  1   Device Type              149 non-null    object
#  2   Sim Capability           147 non-null    object
#  3   Input Mechanism          150 non-null    object
#  4   Availability             149 non-null    object
#  5   Software                 149 non-null    object
#  6   Processor                149 non-null    object
#  7   Internal Memory          148 non-null    object
#  8   Internal Storage         148 non-null    object
#  9   Dedicated Micro SD Card  147 non-null    object
#  10  3.5 mm Jack              141 non-null    object
#  11  Display Technology       148 non-null    object
#  12  Display Size             150 non-null    object
#  13  Display Resolution       149 non-null    object
#  14  Main Camera              147 non-null    object
#  15  Main Camera resolution   150 non-null    object
#  16  Front Camera             150 non-null    object
#  17  Front Camera Resolution  147 non-null    object
#  18  Battery Capacity         150 non-null    object
#  19  USB Type                 147 non-null    object
#  20  Fast Charging            148 non-null    object
#  21  Wireless Charging        148 non-null    object
#  22  Network Type             150 non-null    object
#  23  Network Capability       150 non-null    object
#  24  Fingerprint Sensor       148 non-null    object
#  25  Face Unlock              148 non-null    object
#  26  price                    150 non-null    object
#  27  IP Rating                11 non-null     object
#  28  SD Card Capacity         38 non-null     object
#  29  Dual Sim Capability      1 non-null      object
# dtypes: object(30)
# memory usage: 35.3+ KB

# %%
df.fillna('none',inplace=True)

# %%
df
# Out:
#                        name Device Type Sim Capability Input Mechanism  \
# 0                 Realme 8i  Smartphone       Dual-SIM     Touchscreen
# 1              Realme 8s 5G  Smartphone       Dual-SIM     Touchscreen
# 2     Xiaomi Redmi 10 Prime  Smartphone       Dual-SIM     Touchscreen
# 3    Samsung Galaxy A52s 5G  Smartphone       Dual-SIM     Touchscreen
# 4     Samsung Galaxy M32 5G  Smartphone       Dual-SIM     Touchscreen
# ..                      ...         ...            ...             ...
# 145                Vivo Y11  Smartphone       Dual-SIM     Touchscreen
# 146              Realme C11  Smartphone       Dual-SIM     Touchscreen
# 147             Poco M2 Pro  Smartphone       Dual-SIM     Touchscreen
# 148            OnePlus Nord  Smartphone       Dual-SIM     Touchscreen
# 149               Realme X3  Smartphone           none          QWERTY
#
#             Availability                            Software  \
# 0     Available In India  realme UI 2.0  Based on Android 11
# 1     Available In India  realme UI 2.0  Based on Android 11
# 2     Available In India       MIUI 12.5 based on Android 11
# 3     Available In India                          Android 11
# 4     Available In India                          Android 11
# ..                   ...                                 ...
# 145   Available In India    Funtouch OS 9 Based on Android 9
# 146   Available In India       Realme UI Based on Android 10
# 147   Available In India         MIUI 11 based on Android 10
# 148   Available In India        OxygenOS based on Android 10
# 149   Available in India                          Android 10
#
#                          Processor Internal Memory Internal Storage  \
# 0               MediaTek Helio G96             4GB             64GB
# 1        MediaTek Dimensity 810 5G             6GB            128GB
# 2               MediaTek Helio G88             4GB             64GB
# 3         Qualcomm Snapdragon 778G             6GB            128GB
# 4           MediaTek Dimensity 720             6GB            128GB
# ..                             ...             ...              ...
# 145        Qualcomm Snapdragon 439           3GB               32GB
# 146             MediaTek Helio G35            2GB              32GB
# 147       Qualcomm Snapdragon 720G             4GB             64GB
# 148      Qualcomm Snapdragon 765G              6GB             64GB
# 149  Snapdragon 855 Plus processor       6GB+128GB             none
#
#     Dedicated Micro SD Card  ... Fast Charging Wireless Charging Network Type  \
# 0                       Yes  ...           Yes                No          GSM
# 1                       Yes  ...           Yes                No          GSM
# 2                       Yes  ...           Yes                No          GSM
# 3                       Yes  ...           Yes                No          GSM
# 4                       Yes  ...           Yes                No          GSM
# ..                      ...  ...           ...               ...          ...
# 145                     Yes  ...            No                No          GSM
# 146                     Yes  ...            No                No          GSM
# 147                     Yes  ...           Yes                No          GSM
# 148                     Yes  ...           Yes            Select          GSM
# 149                    none  ...          none              none   2G, 3G, 4G
#
#     Network Capability     Fingerprint Sensor Face Unlock    price IP Rating  \
# 0           2G, 3G, 4G           Side-Mounted         Yes   13,999      none
# 1       2G, 3G, 4G, 5G           Side-Mounted         Yes   17,999      none
# 2           2G, 3G, 4G           Side-Mounted         Yes   12,499      none
# 3           2G, 3G, 4G          Under-Display         Yes   35,999      none
# 4       2G, 3G, 4G, 5G           Side-Mounted         Yes   20,999      none
# ..                 ...                    ...         ...      ...       ...
# 145         2G, 3G, 4G           Rear-Mounted          No    9,990      none
# 146         2G, 3G, 4G  No Fingerprint Sensor          No    7,499      none
# 147         2G, 3G, 4G           Side-Mounted         Yes   13,999      none
# 148     2G, 3G, 4G, 5G          Under-Display         Yes   24,999      none
# 149           2G,3G,4G                   none        none   24,999      none
#
#     SD Card Capacity Dual Sim Capability
# 0               none                none
# 1               none                none
# 2               none                none
# 3               none                none
# 4               none                none
# ..               ...                 ...
# 145           256GB                 none
# 146           256 GB                none
# 147            512GB                none
# 148             none                none
# 149             none            Dual Sim
#
# [150 rows x 30 columns]

# %%
df.shape
# Out:
# (150, 30)

# %%
df['Display Resolution'].unique()
# Out:
# array(['1080x2412', '2400*1080', '2400 x 1080', '1080 x 2400', '720x1600',
#        '1080x2408', '2400x1080', '720x1,560', '1080x2400', '1,080x2,640',
#        '720x1,600', '2408×1080', '1080x2460', '1560 x 720', '1600X720',
#        '1,080x2,460', '1,080x2,400', '2340 x 1080', '1080 x 2408',
#        '1080*2460', '1600x720', '2340x1080 FHD+', '2400 x 1080 (FHD+)',
#        '1600x720 (HD+)', '2404×1080 (FHD+)', '720 x 1600 (HD+)',
#        '1440x3200', '2400x1080 FHD+', '1080×2400 FHD+', '1080×2400',
#        '1080x2376', '3216 X 1440 pixels', '2400 x 1080 pixels',
#        '1080x2400 pixels', '1,080x,2,400 pixels', '2448x1080 FHD+',
#        '720x1,600 pixels', '1600 x 720 Pixels', '2400x1080 ',
#        '2400 x 1080 FHD+', '1080x2340 pixels', '2400 x 1080FHD+',
#        '720*1600', '1640 x 720', '1,080x2,400 pixels', '720x1,560 pixels',
#        '720 x 1520 pixels', '2408 × 1080 (FHD+)', 'none', '1600*720',
#        '2408 × 1080', '1560×720', '2400 x 1080 ', 'Full HD+',
#        '720 x 1600 pixels', '1600×720', '2340x1080 ', '720x1640',
#        '2400×1080 (FHD+)', '1600x720 HD+', '720*1640', '720x1600 ',
#        'FHD+', '1080 x 2340', '2,532x1,170 pixels', 'HD+', 'Full-HD+',
#        '2400x1080 pixels', '1600x720 HD +', '2400 * 1080 (FHD+)',
#        '1080 x 2400 (FHD+)', 'HD+ IPS', '720×1,600', '1,080x2,340 pixels',
#        '1480 x 720 (HD+)', '1640 x 720 Pixels', '720 x 1520 (HD+)',
#        '720 × 1544 (HD+)', '1080 x 2400 pixels'], dtype=object)
